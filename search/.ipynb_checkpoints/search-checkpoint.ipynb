# %%
from vector_search import VectorSearch

# %%
def test_basic_search():
    """기본 벡터 검색 테스트"""
    print("=" * 80)
    print("벡터 검색 테스트")
    print("=" * 80)
    
    # Vector Search 초기화
    search = VectorSearch(bedrock_region='us-west-2')
    
    # 테스트 쿼리들
    test_queries = [
        "The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.",
        "A young wizard discovers his magical heritage and attends a school of witchcraft.",
        "A team of superheroes must unite to save the world from an alien invasion.",
        "A romantic comedy about two people who fall in love in New York City."
    ]
    
    # 각 쿼리로 검색 수행
    for i, query in enumerate(test_queries, 1):
        print(f"\n{'='*80}")
        print(f"테스트 {i}/{len(test_queries)}")
        print(f"{'='*80}")
        
        results = search.perform_vector_search(query, top_k=3)
        
        if results:
            print(f"✅ {len(results)}개 결과 찾음")
        else:
            print("⚠️  결과 없음")
    
    print("\n" + "=" * 80)
    print("✅ 모든 테스트 완료!")
    print("=" * 80)

# %%
def test_cypher_search():
    """Cypher 직접 사용 검색 테스트"""
    print("=" * 80)
    print("Cypher 벡터 검색 테스트")
    print("=" * 80)
    
    search = VectorSearch(bedrock_region='us-west-2')
    
    query = "A thrilling action movie with car chases and explosions"
    
    results = search.perform_vector_search_cypher(query, top_k=5)
    
    if results:
        print(f"\n✅ {len(results)}개 결과 찾음")
    else:
        print("\n⚠️  결과 없음")

# %%
def test_hop_search():
    """Hop 검색 테스트"""
    print("=" * 80)
    print("벡터 검색 + Hop 테스트")
    print("=" * 80)
    
    search = VectorSearch(bedrock_region='us-west-2')
    
    # 1-Hop 테스트
    print("\n" + "=" * 80)
    print("1-Hop: 영화 + 장르/배우/감독/제작사")
    print("=" * 80)
    query = "A romantic comedy about falling in love in a big city"
    results = search.perform_vector_search_with_hop(query, top_k=3, hop_depth=1)
    
    if results:
        print(f"\n✅ {len(results)}개 결과 찾음")
    
    # 2-Hop 테스트
    print("\n" + "=" * 80)
    print("2-Hop: 영화 + 관련 정보 + 배우의 다른 영화")
    print("=" * 80)
    query = "Science fiction movie about space exploration"
    results = search.perform_vector_search_with_hop(query, top_k=2, hop_depth=2)
    
    if results:
        print(f"\n✅ {len(results)}개 결과 찾음")

# %%
# 기본 검색 테스트
test_basic_search()
# Out:
# ================================================================================
# 벡터 검색 테스트
# ================================================================================
# ✅ Neptune 연결 준비 완료
#    Graph ID: g-z8n5so6q32
#    Region: us-east-1
# ✅ Vector Search 초기화 완료
#
# ================================================================================
# 테스트 1/4
# ================================================================================
#
# 🔍 벡터 검색 수행: 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.'
#    Top-K: 3
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (3개):
# ================================================================================
# Title: Ran (1985-06-01)
# Overview: Set in Japan in the 16th century (or so), an elderly warlord retires, handing over his empire to his three sons. However, he vastly underestimates how the new-found power will corrupt them, or cause t...
# Score: 1.0907
# --------------------------------------------------------------------------------
# Title: Jane Austen's Mafia! (1998-07-24)
# Overview: Takeoff on the Godfather with the son of a mafia king taking over for his dying father....
# Score: 1.0331
# --------------------------------------------------------------------------------
# Title: Mad Dog Time (1996-11-08)
# Overview: With his boss in the madhouse, a mobster is temporary boss of the criminal empire just as vicious rivals threaten the control of the empire....
# Score: 1.0172
# --------------------------------------------------------------------------------
# ✅ 3개 결과 찾음
#
# ================================================================================
# 테스트 2/4
# ================================================================================
#
# 🔍 벡터 검색 수행: 'A young wizard discovers his magical heritage and attends a school of witchcraft.'
#    Top-K: 3
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (3개):
# ================================================================================
# Title: The Craft (1996-05-03)
# Overview: A Catholic school newcomer falls in with a clique of teen witches who wield their powers against all who dare to cross them -- be they teachers, rivals or meddlesome parents....
# Score: 0.9947
# --------------------------------------------------------------------------------
# Title: Harry Potter and the Philosopher's Stone (2001-11-16)
# Overview: Harry Potter has lived under the stairs at his aunt and uncle's house his whole life. But on his 11th birthday, he learns he's a powerful wizard -- with a place waiting for him at the Hogwarts School ...
# Score: 0.9928
# --------------------------------------------------------------------------------
# Title: Magic Boy (1959-12-25)
# Overview: A young Japanese boy climbs a mountain in search of a magic wizard. The youth finds the wizard, and is tutored by him. Reinforced with magic powers, the boy eventually fights, and defeats the evil wit...
# Score: 0.9495
# --------------------------------------------------------------------------------
# ✅ 3개 결과 찾음
#
# ================================================================================
# 테스트 3/4
# ================================================================================
#
# 🔍 벡터 검색 수행: 'A team of superheroes must unite to save the world from an alien invasion.'
#    Top-K: 3
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (3개):
# ================================================================================
# Title: Justice League: The New Frontier (2008-02-26)
# Overview: The human race is threatened by a powerful creature, and only the combined power of Superman, Batman, Wonder Woman, Green Lantern, Martian Manhunter and The Flash can stop it. But can they overcome th...
# Score: 1.0495
# --------------------------------------------------------------------------------
# Title: Three Supermen in the Jungle (1970-02-27)
# Overview: Three superheroes attempt to reclaim the stolen lease of a uranium mine....
# Score: 1.0205
# --------------------------------------------------------------------------------
# Title: Justice League: War (2014-02-02)
# Overview: The world is under attack by an alien armada led by the powerful Apokoliptian, Darkseid. A group of superheroes consisting of Superman, Batman, Wonder Woman, The Flash, Green Lantern, Cyborg, and Shaz...
# Score: 0.8673
# --------------------------------------------------------------------------------
# ✅ 3개 결과 찾음
#
# ================================================================================
# 테스트 4/4
# ================================================================================
#
# 🔍 벡터 검색 수행: 'A romantic comedy about two people who fall in love in New York City.'
#    Top-K: 3
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (3개):
# ================================================================================
# Title: The Age of Innocence (1934-09-14)
# Overview: An engaged attorney and a divorcee fall for each other in 1870s Manhattan....
# Score: 1.1089
# --------------------------------------------------------------------------------
# Title: Adam & Steve (2006-03-31)
# Overview: Follows two New York city couples -- one heterosexual and one gay who explore the peaks and the valleys of their respective relationships....
# Score: 0.9466
# --------------------------------------------------------------------------------
# Title: Peter and Vandy (2009-01-01)
# Overview: Flashbacks and flash-forwards illustrate the rise and fall of a love affair between two New Yorkers....
# Score: 0.9233
# --------------------------------------------------------------------------------
# ✅ 3개 결과 찾음
#
# ================================================================================
# ✅ 모든 테스트 완료!
# ================================================================================

# %%
test_cypher_search()
# Out:
# ================================================================================
# Cypher 벡터 검색 테스트
# ================================================================================
# ✅ Vector Search 초기화 완료
#
# 🔍 Neptune 벡터 검색 수행: 'A thrilling action movie with car chases and explosions'
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (5개):
# ================================================================================
# Title: The Immortals (1995-10-05)
# Overview: An elaborate heist unites 8 strangers in a simultaneous assault on targets all over the city- and explodes in a hailstorm of gunfire and high-speed chases in this powerful action-thriller.  Recruited ...
# Score: 1.2082
# --------------------------------------------------------------------------------
# Title: Black Cadillac (2003-01-01)
# Overview: Three young men become terrorized in a high-speed car chase with a mysterious pursuant....
# Score: 1.2048
# --------------------------------------------------------------------------------
# Title: One Man Force (1989-09-21)
# Overview: In this action packed film, an L.A. cop speeds off to get revenge upon the dirty drug-dealing dogs who killed his partner...
# Score: 1.1899
# --------------------------------------------------------------------------------
# Title: Fast Track: No Limits (2008-02-21)
# Overview: An action movie centered around a group of street racers....
# Score: 1.1076
# --------------------------------------------------------------------------------
# Title: Sunburn (1979-08-10)
# Overview: An enthralling &amp; action-packed comedy-thriller, full of blistering excitement....
# Score: 1.0990
# --------------------------------------------------------------------------------
#
# ✅ 5개 결과 찾음

# %%
test_hop_search()
# Out:
# ================================================================================
# 벡터 검색 + Hop 테스트
# ================================================================================
# ✅ Vector Search 초기화 완료
#
# ================================================================================
# 1-Hop: 영화 + 장르/배우/감독/제작사
# ================================================================================
#
# 🔍 벡터 검색 + 1-Hop 그래프 탐색: 'A romantic comedy about falling in love in a big city'
#    Top-K: 3
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (3개) with 1-Hop:
# ================================================================================
#
# 1. Broadway Damage (1997-08-26)
#    Score: 1.1522
#    Runtime: 0.0 min
#    Directors: Victor Mignatti
#    Top Actors: Michael Shawn Lucas, Mara Hobel, Hugh Panaro
#    Overview: Romantic comedy about aspiring writers in NY....
# --------------------------------------------------------------------------------
#
# 2. E Aí... Comeu? (2012-06-22)
#    Score: 1.1193
#    Runtime: 100.0 min
#    Genres: Comedy
#    Directors: Felipe Joffily
#    Top Actors: Seu Jorge, Julia Farsette, Katiuscia Canoro, Paula Cohen, Juliana Helcer
#    Production: Globo Filmes, Paris Filmes, Casé Filmes
#    Overview: The real first comedy about love....
# --------------------------------------------------------------------------------
#
# 3. Annie Hall (1977-04-19)
#    Score: 1.1132
#    Runtime: 93.0 min
#    Genres: Comedy, Drama, Romance
#    Top Actors: Johnny Haymer, Ruth Volner, Mordecai Lawner, Chris Gampel, Russell Horton
#    Production: United Artists
#    Overview: In the city of New York, comedian Alvy Singer falls in love with the ditsy Annie Hall....
# --------------------------------------------------------------------------------
#
# ✅ 3개 결과 찾음
#
# ================================================================================
# 2-Hop: 영화 + 관련 정보 + 배우의 다른 영화
# ================================================================================
#
# 🔍 벡터 검색 + 2-Hop 그래프 탐색: 'Science fiction movie about space exploration'
#    Top-K: 2
#    📝 쿼리 임베딩 생성 중...
#
# 📊 검색 결과 (2개) with 2-Hop:
# ================================================================================
#
# 1. Alien Origin (2012-06-12)
#    Score: 1.1110
#    Runtime: 90.0 min
#    Genres: Fantasy, Thriller, Science Fiction
#    Overview: A movie created from "found footage" of a lost military expedition that exposes the origins of life on earth....
# --------------------------------------------------------------------------------
#
# 2. Gagarin: First in Space (2013-06-05)
#    Score: 1.0571
#    Runtime: 108.0 min
#    Genres: History, Drama
#    Directors: Pavel Parkhomenko
#    Top Actors: Mikhail Filippov, Sergey Kalashnikov, Sergei Laktuynkin, Viktor Proskurin, Anatoliy Otradnov
#    Production: Kremlin Films
#    Related Movies (by actors): A Cruel Romance, The Conductor, Everybody Dies But Me, Alexandra, In the Fog
#    Overview: The film is dedicated to the first steps of mankind on the path of space exploration and direct the fate of the first cosmonaut Yuri Gagarin. The main...
# --------------------------------------------------------------------------------
#
# ✅ 2개 결과 찾음
